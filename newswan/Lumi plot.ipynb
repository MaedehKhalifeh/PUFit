# %%
from bs4 import BeautifulSoup
import matplotlib.pyplot as plt
import numpy as np

# %%
with open('https://swan-k8s.cern.ch/user/mkhalife/view/eos/newRes/expe%3D000CMainLumiQ%3D0.05%2C0.24_ZeroBias22C2022_nLumiBins%3D6_nRuns%3D186/overview/LumiDistBiningTrue.html', 'r') as file:
    html_plot_1 = file.read()

with open('https://swan-k8s.cern.ch/user/mkhalife/view/eos/newRes/expe%3D000BMainLumiQ%3D0.07%2C0.256_ZeroBias22B2022_nLumiBins%3D6_nRuns%3D51/overview/LumiDistBiningTrue.html', 'r') as file:
    html_plot_2 = file.read()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /tmp/ipykernel_1082/3308421983.py in <module>
# ----> 1 with open('https://swan-k8s.cern.ch/user/mkhalife/view/eos/newRes/expe%3D000CMainLumiQ%3D0.05%2C0.24_ZeroBias22C2022_nLumiBins%3D6_nRuns%3D186/overview/LumiDistBiningTrue.html', 'r') as file:
#       2     html_plot_1 = file.read()
#       3
#       4 with open('https://swan-k8s.cern.ch/user/mkhalife/view/eos/newRes/expe%3D000BMainLumiQ%3D0.07%2C0.256_ZeroBias22B2022_nLumiBins%3D6_nRuns%3D51/overview/LumiDistBiningTrue.html', 'r') as file:
#       5     html_plot_2 = file.read()
#
# FileNotFoundError: [Errno 2] No such file or directory: 'https://swan-k8s.cern.ch/user/mkhalife/view/eos/newRes/expe%3D000CMainLumiQ%3D0.05%2C0.24_ZeroBias22C2022_nLumiBins%3D6_nRuns%3D186/overview/LumiDistBiningTrue.html'

# %%
# Example HTML plots (replace this with your actual HTML content)
html_plot_1 = """
<div>
    <h2>Plot 1</h2>
    <img src="..._DATA_1" alt="Plot 1">
</div>
"""

html_plot_2 = """
<div>
    <h2>Plot 2</h2>
    <img src="..._DATA_2" alt="Plot 2">
</div>
"""

# Dummy base64 encoded image data (replace with your actual image data)
IMAGE_DATA_1 = "dummy_base64_encoded_data_1"
IMAGE_DATA_2 = "dummy_base64_encoded_data_2"

# Parse HTML plots
soup1 = BeautifulSoup(html_plot_1, 'html.parser')
soup2 = BeautifulSoup(html_plot_2, 'html.parser')

# Extract image data
image_data_1 = IMAGE_DATA_1  # You would parse this from soup1
image_data_2 = IMAGE_DATA_2  # You would parse this from soup2

# Generate data for the new plot
x = np.linspace(0, 10, 100)
y1 = np.sin(x)
y2 = np.cos(x)

# Plot the new data
plt.plot(x, y1, label='Plot 1')
plt.plot(x, y2, label='Plot 2')

# Customize colors
plt.gca().get_lines()[0].set_color('red')  # Change color of Plot 1
plt.gca().get_lines()[1].set_color('blue') # Change color of Plot 2

# Add legend
plt.legend()

# Show the plot
plt.show()
